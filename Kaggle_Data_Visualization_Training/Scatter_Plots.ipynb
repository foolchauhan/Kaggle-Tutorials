# %% [markdown]
# # Scatter Plots
# ***

# %% [markdown]
# ## Inroduction

# %% [markdown]
# In this tutorial, we'll learn how to create advanced scatter plots.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Set Up The Notebook

# %%
import pandas as pd

# Register Pandas Formatters and Converters with matplotlib
# This function modifies the global matplotlib.units.registry dictionary. Pandas adds custom converters for
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt

# This code is used in Jupyter Notebook for inline representation of graphs
# %matplotlib inline

import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Select a Dataset

# %% [markdown]
# We'll work with a (synthetic) dataset of insurance charges, to see if we can understand why some customers pay more than others.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Load The Data

# %%
# Path of the file to read
insurance_filepath = "../Resources/insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Examine the Data

# %%
# Print the first five rows of the dataset
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# To create a simple scatter plot, we use the __sns.scatterplot__ command and specify the values for:
#
# - the horizontal x-axis __(x=insurance_data\['bmi'\])__, and
# - the vertical y-axis __(y=insurance_data\['charges'\]__).

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are __positively correlated__, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)

# %% [markdown]
# <br>
#
# To double-check the strength of this relationship, you might like to add a __regression line__, or the line that best fits the data. We do this by changing the command to sns.regplot.

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Color-coded Scatter Plots

# %% [markdown]
# We can use scatter plots to display the relationships between (not two, but...) three variables! One way of doing this is by color-coding the points.

# %% [markdown]
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by __'smoker'__, and plot the other two columns (__'bmi'__, __'charges'__) on the axes.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])

# %% [markdown]
# <br>
#
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.

# %% [markdown]
# To further emphasize this fact, we can use the __sns.lmplot__ command to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# <br>
#
# The __sns.lmplot__ command above works slightly differently than the commands you have learned about so far:
# - Instead of setting __x=insurance_data['bmi']__ to select the __'bmi'__ column in insurance_data, we set __x="bmi"__ to specify the name of the column only.
# - Similarly, __y="charges"__ and __hue="smoker"__ also contain the names of columns.
# - We specify the dataset with data=insurance_data.

# %% [markdown]
# Finally, there's one more plot that you'll learn about, that might look slightly different from how you're used to seeing scatter plots. Usually, we use scatter plots to highlight the relationship between two continuous variables (like __"bmi"__ and __"charges"__). However, we can adapt the design of the scatter plot to feature a categorical variable (like __"smoker"__) on one of the main axes. We'll refer to this plot type as a __categorical scatter plot__, and we build it with the __sns.swarmplot__ command.

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])

# %% [markdown]
# <br>
#
# Among other things, this plot shows us that:
# - on average, non-smokers are charged less than smokers, and
# - he customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Your Turn
